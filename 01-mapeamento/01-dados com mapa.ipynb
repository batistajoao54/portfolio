# %% [markdown]
# # Nesse projeto construirei um mapa com os dados da tabela informando o preço e a localização.

# %%
import pandas as pd   #biblioteca que permite que leiamos xlsx, csv, e outros
import plotly.express as px #biblioteca que permite que criamos graficos/mapas

# %%
df = pd.read_csv('kc_house_data.csv') #importando os dados para dentro do python
df.head() # mostrando o cabeçalho desses dados
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
dados = df[['id', 'lat', 'long', 'price']] #separando os dados que iremos usar no grafico

# %%
#criando o grafico
fig = px.scatter_mapbox(dados,
                       lat = 'lat',
                       lon = 'long',
                       hover_name = 'id',
                       size = 'price',
                       color_continuous_scale = px.colors.cyclical.IceFire,
                       size_max = 15,
                       zoom = 10)
fig.update_layout(mapbox_style = 'open-street-map')
fig.update_layout(height = 600,
                 margin = {
                     'r':0,
                     't':0,
                     'l':0,
                     'b':0
                 }
                 )
# Out:
# <div>                            <div id="1799c4eb-5faa-4297-af1d-bf2d5081adcc" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1799c4eb-5faa-4297-af1d-bf2d5081adcc")) {                    Plotly.newPlot(                        "1799c4eb-5faa-4297-af1d-bf2d5081adcc",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>price=%{marker.size}<br>lat=%{lat}<br>long=%{lon}<extra></extra>","hovertext":["7129300520","6414100192","5631500400","2487200875","1954400510","7237550310","1321400060","2008000270","2414600126","3793500160","1736800520","9212900260","114101516","6054650070","1175000570","9297300055","1875500060","6865200140","16000397","7983200060","6300500875","2524049179","7137970340","8091400200","3814700200","1202000200","1794500
# ...

# %%
# a imagem abaixo é uma arquivo png, pois não conseguir fazer o github abrir o original (html), que é interativo (podemos
# dar zomm movimentar o grafico.)

# %% [markdown]
# # ![newplot%20%283%29.png](attachment:newplot%20%283%29.png)

# %%
#salvando o mapa em html
fig.write_html('mapa_localizaçao_preço.html')
